# %% [markdown]
# <a href="https://colab.research.google.com/github/arjunnajahattamim-rgb/ARJUN-NAJAH-ATTAMIM/blob/tugas/TUGAS_HITUNG_LUAS_KELILING_PERSEGI_PANJANG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program Penjumlahan Dua Bilangan

angka1 = float(input("Masukkan angka pertama: "))
angka2 = float(input("Masukkan angka kedua: "))

hasil = angka1 + angka2

print("Hasil penjumlahan:", hasil)
# Out:
# Masukkan angka pertama: 4
# Masukkan angka kedua: 3
# Hasil penjumlahan: 7.0

# %%
# Program Mengecek Cukup Umur

nama = input("Masukkan nama Anda: ")
umur = int(input("Masukkan umur Anda: "))

if umur >= 18:
    print(nama, "sudah cukup umur (>= 18 tahun).")
else:
    print(nama, "belum cukup umur (< 18 tahun).")
# Out:
# Masukkan nama Anda: XIE CHUN
# Masukkan umur Anda: 18
# XIE CHUN sudah cukup umur (>= 18 tahun).

# %%
# Program menghitung luas dan keliling persegi panjang

panjang = float(input("Masukkan panjang persegi panjang: "))
lebar = float(input("Masukkan lebar persegi panjang: "))

luas = panjang * lebar
keliling = 2 * (panjang + lebar)

print("\nHasil Perhitungan:")
print("Luas persegi panjang    =", luas)
print("Keliling persegi panjang =", keliling)
# Out:
# Masukkan panjang persegi panjang: 55
# Masukkan lebar persegi panjang: 35
#
# Hasil Perhitungan:
# Luas persegi panjang    = 1925.0
# Keliling persegi panjang = 180.0
